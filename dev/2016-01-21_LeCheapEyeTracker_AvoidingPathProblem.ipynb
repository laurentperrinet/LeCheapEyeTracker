# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import LeCheapEyeTracker
import numpy as np
import cv2

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### We have to reverse decoding and encoding: the PNG image

# %% [markdown]
# http://imageio.readthedocs.org/en/latest/examples.html#read-an-image-of-a-cat

# %%
my_png_as_a_string = LeCheapEyeTracker.constants.png_string
print(type(my_png_as_a_string), my_png_as_a_string[:10])
# Out:
# <class 'str'> iVBORw0KGg

# %%
img_bytes = str.encode(LeCheapEyeTracker.constants.png_string)

# %%
import imageio
import base64
image = imageio.imread(base64.b64decode(LeCheapEyeTracker.constants.png_string))

# %%
import matplotlib.pyplot as plt
plt.imshow(image[:, :, (2, 1, 0)])

# %%
plt.imshow(image.sum(axis=-1), cmap=plt.gray())

# %% [markdown]
# ### We have to reverse decoding and encoding: the cascade file

# %%
type(LeCheapEyeTracker.constants.xml_string)
# Out:
# str

# %%
import cv2
face_cascade = cv2.CascadeClassifier('/usr/local/Cellar/opencv3/3.1.0_1/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml')

# %%
help(cv2.CascadeClassifier_convert)
# Out:
# Help on built-in function CascadeClassifier_convert:
#
# CascadeClassifier_convert(...)
#     CascadeClassifier_convert(oldcascade, newcascade) -> retval

# %%
help(cv2.CascadeClassifier)
# Out:
# Help on built-in function CascadeClassifier:
#
# CascadeClassifier(...)
#     CascadeClassifier([filename]) -> <CascadeClassifier object>

# %%
face_cascade = cv2.CascadeClassifier()

# %%
help(face_cascade.read)
# Out:
# Help on built-in function read:
#
# read(...) method of cv2.CascadeClassifier instance
#     read(node) -> retval

# %%
with open('/usr/local/Cellar/opencv3/3.1.0_1/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml'
, 'r') as f:
    #face_cascade.read(f)
    node = cv2.FileNode(f)
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-12-42c8c0da0d58> in <module>()
#       2 , 'r') as f:
#       3     #face_cascade.read(f)
# ----> 4     node = cv2.FileNode(f)
#
# SystemError: <built-in function FileNode> returned NULL without setting an error

# %%
help(cv2.FileNode)
# Out:
# Help on built-in function FileNode:
#
# FileNode(...)
#     FileNode() -> <FileNode object>

# %%
fs = cv2.Filestorage('/usr/local/Cellar/opencv3/3.1.0_1/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-925f4fb4757c> in <module>()
# ----> 1 fs = cv2.Filestorage('/usr/local/Cellar/opencv3/3.1.0_1/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml')
#
# AttributeError: module 'cv2' has no attribute 'Filestorage'

# %%
fs = cv2.FileStorage()

# %%
fs.open('/usr/local/Cellar/opencv3/3.1.0_1/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-4d7c6b8c94bf> in <module>()
# ----> 1 fs.open('/usr/local/Cellar/opencv3/3.1.0_1/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml')
#
# TypeError: Required argument 'flags' (pos 2) not found
