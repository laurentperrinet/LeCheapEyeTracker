# %%
from SimpleCV import Camera, init_options_handler

init_options_handler.enable_notebook()

# %%
cam = Camera()
img = cam.getImage()
img.show()
# Out:
# <SimpleCV.Display Object resolution:((640, 480)), Image Resolution: (0, 0) at memory location: (0x109916368)>
